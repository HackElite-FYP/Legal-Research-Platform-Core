# %% [markdown]
# <a href="https://colab.research.google.com/github/HackElite-FYP/Legal-Research-Platform-Core/blob/feature%2Fentity-mapping/entity-mapping/cases%2C%20acts%20reference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install neo4j
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.3/312.3 kB 4.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 📦 Required imports
import json
import re
import pandas as pd
from neo4j import GraphDatabase
from IPython.display import display

# %%
DOC_YEAR = '2024'
filename = "cases_2024_v2.json"
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1meeq_pyxndS9W7mmavcX_srExlpYi5Hw' -O {filename}
# Out:
# --2025-07-23 06:17:44--  https://docs.google.com/uc?export=download&id=1meeq_pyxndS9W7mmavcX_srExlpYi5Hw
# Resolving docs.google.com (docs.google.com)... 142.250.98.102, 142.250.98.101, 142.250.98.138, ...
# Connecting to docs.google.com (docs.google.com)|142.250.98.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1meeq_pyxndS9W7mmavcX_srExlpYi5Hw&export=download [following]
# --2025-07-23 06:17:44--  https://drive.usercontent.google.com/download?id=1meeq_pyxndS9W7mmavcX_srExlpYi5Hw&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 192.178.219.132, 2607:f8b0:400c:c0d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|192.178.219.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30688975 (29M) [application/octet-stream]
# Saving to: ‘cases_2024_v2.json’
#
# ...

# %%
# 📁 Configuration and Data Loading

# CHANGE THIS LINE to point to your file path
file_path = r"cases_2024_v2.json"

try:
    with open(file_path, 'r', encoding='utf-8') as file:
        case_data = json.load(file)
    print(f"✅ Successfully loaded {len(case_data)} records from case data.")
except FileNotFoundError:
    print(f"❌ Error: The file was not found at {file_path}")
    print("Please ensure the file path is correct and that your Google Drive is mounted if you're using Colab.")
    case_data = []
# Out:
# ✅ Successfully loaded 530 records from case data.

# %%
# 📌 Define function to extract and format acts in "Act Name, No. X of YYYY" format
def extract_acts(text):
    pattern = r'([A-Z][a-zA-Z\s()]*?Act(?:,?|\s+))\s*No\.?\s*(\d+)\s*(?:of)?\s*(\d{4})'
    matches = re.findall(pattern, text)
    return [f"{name.strip()}, No. {num} of {year}" for name, num, year in matches]

# 🧠 Process each case's content
raw_case_act_map = []
if case_data:
    print("Processing case data to extract raw act references...")
    for case in case_data:
        case_id = case.get("id", "Unknown")
        file_name = case.get("filename", "")

        content = case.get("translated", "").replace('\n', ' ')

        # 🔍 Use the extract_acts function instead of inline regex
        acts_found = extract_acts(content)
        filtered_acts = []
        for act in acts_found:
            if len(act.split()) < 10:
                filtered_acts.append(act)

        if filtered_acts:
            raw_case_act_map.append({
                "case_id": case_id,
                "filename":file_name,
                "raw_acts": sorted(list(set(filtered_acts)))
            })
        else:
            print(f"⚠️ No act references found in case {case_id}")
            raw_case_act_map.append({
                "case_id": case_id,
                "filename":file_name,
                "raw_acts": []
            })

    print(f"✅ Extraction complete. Found act references in {len(raw_case_act_map)} cases.")
else:
    print("⚠️ No case data to process.")

# 📊 Preview the result
raw_df = pd.DataFrame(raw_case_act_map)
print("\n📋 Preview of Extracted and Formatted Act References:")
display(raw_df)
# Out:
# Processing case data to extract raw act references...
# ⚠️ No act references found in case 8fb1373c-2b19-4df4-bbcc-40b0720dc9b3
# ⚠️ No act references found in case f377d509-ea0d-4a2f-9e7a-4d2a14515d19
# ⚠️ No act references found in case 3f222e28-d9a0-452e-aa98-498d5656613e
# ⚠️ No act references found in case eaaf5922-459d-46c6-8a6d-7d943cf59802
# ⚠️ No act references found in case 8a23d9c9-b5b6-4c47-87ef-ab9d38ab5272
# ⚠️ No act references found in case 70e90de1-f93f-48d9-840a-6a2b1b067278
# ⚠️ No act references found in case 8a1844b8-851e-4ad5-ae21-ce790eb9c199
# ⚠️ No act references found in case 1879977a-a086-41c6-a1e3-5fc4fcf05ab1
# ⚠️ No act references found in case 1fd3711c-cee9-4d59-9023-a32cd006f8d1
# ⚠️ No act references found in case a8214375-4576-411e-9849-fbb225ce6f16
# ⚠️ No act references found in case 0b62012f-a1fb-435b-80d5-2a867b52ad09
# ⚠️ No act references found in case 2acb30b0-4625-44c1-8e66-4224f774d4bf
# ...

# %%
# 🛠️ Cell 2: Act Standardizer Utility and Final Processing

import re
import pandas as pd

class ActStandardizer:
    """
    A utility class to parse raw act strings into a structured format,
    handling complex names with special provisions.
    """
    def __init__(self):
        # NEW REGEX: Designed to capture the main name, an optional parenthetical part,
        # the keyword, number, and year as separate groups.
        self.parsing_pattern = re.compile(
            # Group 1: The main name part (optional, non-greedy). Handles "bail act" or "Evidence".
            r'((?:[a-z\s]+)?)'
            # Group 2: The parenthetical part, e.g., "(special provision)" (optional).
            r'(?:\s*\((.*?)\))?'
            # Group 3: The keyword itself (e.g., "Act").
            r'\s*(Act|Code|Ordinance|Law|Regulation|Rules)'
            # Optional comma separator
            r'[,]+?\s*'
            # Group 4: The act number.
            r'(?:No\.?|Number)\s*(\d+)\s*'
            # Group 5: The act year.
            r'of\s*(\d{4})',
            re.IGNORECASE
        )

    def standardize(self, raw_act_text):
        """
        Parses a raw act string and returns a dictionary with a fully formatted name.
        """
        match = self.parsing_pattern.search(raw_act_text)

        if not match:
            # If the pattern fails entirely, mark as Unknown.
            return {
                "act_name": "Unknown",
                "act_number": "N/A",
                "year": "N/A"
            }

        # --- Extract all components from the regex match ---
        main_name_part = match.group(1)
        parenthetical_part = match.group(2)
        keyword = match.group(3)
        number = match.group(4)
        year = match.group(5)

        # --- Build the final formatted name string ---
        final_name_parts = []

        # Add the main name part if it exists
        if main_name_part and main_name_part.strip():
            final_name_parts.append(main_name_part.strip().title())

        # Always add the keyword (e.g., "Act", "Code")
        # final_name_parts.append(keyword.capitalize())

        # If a parenthetical part was found, format it and add it
        if parenthetical_part and parenthetical_part.strip():
            final_name_parts.append(f"[{parenthetical_part.strip().lower()}]")

        # Join the parts to create the name. If no name part was found,
        # the list will just contain the keyword, e.g., ['Act'].
        final_name = ' '.join(final_name_parts).lower()
        final_name = re.sub(r'\s+', '-', final_name)

        # If the final name is just the keyword, it means no descriptive name was found.
        if final_name.lower() == keyword.lower():
            final_name = "unknown"

        return {
            "ammend_suffix": 'amendment' if 'amendment' in raw_act_text.lower() else 'original',
            "act_name": final_name,
            "act_number": number,
            "year": year
        }

# %%
# --- Standardization Process ---
standardizer = ActStandardizer()
final_structured_list = []

print("\nStandardizing extracted acts into the final format...")

# Check if the input data from the previous cell exists
if 'raw_case_act_map' in locals() and raw_case_act_map:
    for entry in raw_case_act_map:
        case_id = entry["case_id"]
        if not entry["raw_acts"]:
          print(f"⚠️ No raw acts found for entry: {entry['case_id']}")
          final_structured_list.append({
              "case_id": case_id,
              "filename":entry["filename"],
              "standardized_act": None
          })

        for raw_act in entry["raw_acts"]:
            # Get the structured dictionary with the fully formatted name
            structured_act = standardizer.standardize(raw_act)
            filename = entry["filename"]

            # Format the final string as "Name_X_YYYY"
            formatted_string = f"{structured_act['act_number']}_{structured_act['year']}_{structured_act['ammend_suffix']}"

            final_structured_list.append({
                "case_id": case_id,
                "filename":filename,
                "standardized_act": formatted_string
            })


    final_df = pd.DataFrame(final_structured_list)

    grouped_df = final_df.groupby("case_id").agg({
        "standardized_act": list,
        "filename": "first"
    }).reset_index()

    # Show the final results
    print("✅ Standardization complete.")
    print("\n📋 Final Standardized Act Data (Grouped by Case ID):")
    display(grouped_df)

else:
    print("⚠️ No raw act data (`raw_case_act_map`) found to process. Please run the extraction cell first.")
# Out:
# Standardizing extracted acts into the final format...
# ⚠️ No raw acts found for entry: 8fb1373c-2b19-4df4-bbcc-40b0720dc9b3
# ⚠️ No raw acts found for entry: f377d509-ea0d-4a2f-9e7a-4d2a14515d19
# ⚠️ No raw acts found for entry: 3f222e28-d9a0-452e-aa98-498d5656613e
# ⚠️ No raw acts found for entry: eaaf5922-459d-46c6-8a6d-7d943cf59802
# ⚠️ No raw acts found for entry: 8a23d9c9-b5b6-4c47-87ef-ab9d38ab5272
# ⚠️ No raw acts found for entry: 70e90de1-f93f-48d9-840a-6a2b1b067278
# ⚠️ No raw acts found for entry: 8a1844b8-851e-4ad5-ae21-ce790eb9c199
# ⚠️ No raw acts found for entry: 1879977a-a086-41c6-a1e3-5fc4fcf05ab1
# ⚠️ No raw acts found for entry: 1fd3711c-cee9-4d59-9023-a32cd006f8d1
# ⚠️ No raw acts found for entry: a8214375-4576-411e-9849-fbb225ce6f16
# ⚠️ No raw acts found for entry: 0b62012f-a1fb-435b-80d5-2a867b52ad09
# ⚠️ No raw acts found for entry: 2acb30b0-4625-44c1-8e66-4224f774d4bf
# ⚠️ No raw acts found for entry: 766f067d-f06a-4953-bbe3-444a2c498bd6
# ...

# %%
# 🧠 Neo4j Connector Class

class Neo4jConnector:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        """Closes the database connection."""
        if self.driver:
            self.driver.close()

    def verify_connection(self):
        """Verifies and prints the connection status."""
        self.driver.verify_connectivity()
        print("✅ Connection to Neo4j AuraDB verified successfully.")

    def push_case_with_acts(self, case_id, filename, acts):
        """Pushes a single case and its act relationships to the graph."""
        with self.driver.session(database="neo4j") as session:
            session.execute_write(self._create_graph_tx, case_id, filename, acts)

    @staticmethod
    def _create_graph_tx(tx, case_id, filename, acts):
    # Create or update the Case node with filename
       tx.run(
        """
        MERGE (c:Case {doc_id: $case_id})
        SET c.filename = $filename, c.doc_year = $doc_year
        """, case_id=case_id, filename=filename, doc_year=DOC_YEAR
       )

    # Create Act nodes and relationships
       if acts:
        tx.run(
            """
            UNWIND $acts AS act_name
            MATCH (c:Case {doc_id: $case_id})
            MERGE (a:Act {std_id: act_name})
            MERGE (c)-[:REFERS_TO]->(a)
            SET a.doc_id = $case_id, a.doc_year = $doc_year
            """,
            case_id=case_id,
            acts=acts,
            doc_year=DOC_YEAR
        )


    def set_case_metadata(self, case_id, metadata: dict):
        """Sets or updates metadata for a given Case node."""
        with self.driver.session(database="neo4j") as session:
            session.execute_write(self._update_metadata_tx, case_id, metadata)

    @staticmethod
    def _update_metadata_tx(tx, case_id, metadata: dict):
        # Build a dynamic Cypher SET clause for all metadata keys
        print(metadata)
        set_clause = ', '.join([f"c.{key} = ${key}" for key in metadata])
        parameters = {"case_id": case_id, **metadata}

        query = f"""
        MATCH (c:Case {{doc_id: $case_id}})
        SET {set_clause}
        """

        tx.run(query, parameters)

    def set_act_metadata(self, act_id, metadata: dict,shouldCreate: bool ):
        """Sets or updates metadata for a given Act node."""
        with self.driver.session(database="neo4j") as session:
            session.execute_write(self._update_act_metadata_tx, act_id, metadata, shouldCreate)

    @staticmethod
    def _update_act_metadata_tx(tx, act_id, metadata: dict, shouldCreate: bool):
        set_clause = ', '.join([f"a.{key} = ${key}" for key in metadata])
        parameters = {"act_id": act_id, **metadata} # Include metadata in parameters

        if shouldCreate:
            query = f"""
                MERGE (a:Act {{std_id: $act_id}})
                SET {set_clause}
            """
        else:
            query = f"""
                MATCH (a:Act {{std_id: $act_id}})
                SET {set_clause}
            """

        tx.run(query, parameters)


    def get_acts_for_case(self, case_id):
        """Queries for a case and returns a list of its referred act names."""
        with self.driver.session(database="neo4j") as session:
            return session.read_transaction(self._get_acts_tx, case_id)

    @staticmethod
    def _get_acts_tx(tx, case_id):
        query = (
            "MATCH (c:Case {id: $case_id})-[:REFERS_TO]->(a:Act) "
            "RETURN a.name AS act_name"
        )
        result = tx.run(query, case_id=case_id)
        return [record["act_name"] for record in result]

# %%
# 🚀 Data Ingestion to Neo4j

# --- IMPORTANT ---
# ⚠️ Before running this, clear your database of old, messy data by running this
#    Cypher query in your Neo4j console:
#    MATCH (n) DETACH DELETE n

NEO4J_URI = "neo4j+s://66d16355.databases.neo4j.io"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "G4UXZ6KLGd1dzo57rp6ITypJHZ37aM1fn-exAWdw3p8"

print("--- Phase 1: Data Ingestion ---")
neo4j_conn = None
try:
    neo4j_conn = Neo4jConnector(uri=NEO4J_URI, user=NEO4J_USER, password=NEO4J_PASSWORD)
    neo4j_conn.verify_connection()

    print("Pushing clean, standardized data to Neo4j...\n")

    df_to_process = grouped_df
    # display(df_to_process)
    for _, row in df_to_process.iterrows():
        acts = row["standardized_act"] if row["standardized_act"][0] else None
        neo4j_conn.push_case_with_acts(row["case_id"], row["filename"], acts)
        print(f"==> Pushed case '{row['case_id']}' with {len(acts) if acts else 0} acts.")

        # if pd.notna(row.get("filename")):
        #     neo4j_conn.set_case_metadata(row["case_id"], {"filename": row["filename"]})

    print(f"\n✅ Successfully pushed {len(df_to_process)} cases with standardized act relationships to Neo4j.")


except Exception as e:
    print(f"❌ An error occurred during the Neo4j push operation: {e}")

finally:
    if neo4j_conn:
        neo4j_conn.close()
        print("Neo4j push connection closed.")
# Out:
# --- Phase 1: Data Ingestion ---
# ✅ Connection to Neo4j AuraDB verified successfully.
# Pushing clean, standardized data to Neo4j...
#
# ==> Pushed case '00d8cbe8-f63a-46cb-b5c9-54b2a837e865' with 0 acts.
# ==> Pushed case '01678304-fafe-410c-93c4-9eb6b147acaf' with 0 acts.
# ==> Pushed case '016a8461-93bb-4746-b66c-03ff62926220' with 0 acts.
# ==> Pushed case '01bf4783-e054-4efc-929e-4feb4700d4f8' with 1 acts.
# ==> Pushed case '01f89a02-5e35-4d26-ad0e-8bfd4abe138a' with 0 acts.
# ==> Pushed case '029156bb-e590-44e6-9d47-a6ff2acc578e' with 0 acts.
# ==> Pushed case '02d57e60-700d-4127-983c-128cd5dcfca4' with 2 acts.
# ==> Pushed case '02d66939-df82-416a-8808-4a9961f4f67e' with 0 acts.
# ==> Pushed case '02ed7b72-138a-4cf6-97e5-06b01322fb4c' with 0 acts.
# ==> Pushed case '037b9a0b-478a-48aa-882d-fa1010e9ff3d' with 0 acts.
# ==> Pushed case '05d738bb-6b65-4ab6-87dc-9430ac1db158' with 0 acts.
# ==> Pushed case '064f53c2-43b8-43bf-af14-4677be56b484' with 0 acts.
# ...

# %%
filename = "acts_2024_v2.json"
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1FhOVWqLks7Qvq21U1OKppC5-jHWwWx-5' -O {filename}
# Out:
# --2025-07-23 06:28:41--  https://docs.google.com/uc?export=download&id=1FhOVWqLks7Qvq21U1OKppC5-jHWwWx-5
# Resolving docs.google.com (docs.google.com)... 108.177.12.139, 108.177.12.102, 108.177.12.113, ...
# Connecting to docs.google.com (docs.google.com)|108.177.12.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1FhOVWqLks7Qvq21U1OKppC5-jHWwWx-5&export=download [following]
# --2025-07-23 06:28:41--  https://drive.usercontent.google.com/download?id=1FhOVWqLks7Qvq21U1OKppC5-jHWwWx-5&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 192.178.219.132, 2607:f8b0:400c:c05::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|192.178.219.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1729728 (1.6M) [application/octet-stream]
# Saving to: ‘acts_2024_v2.json’
#
# ...

# %%
# 📁 Configuration and Data Loading
import json

# CHANGE THIS LINE to point to your file path
file_path = r"acts_2024_v2.json"

try:
    with open(file_path, 'r', encoding='utf-8') as file:
        acts_data = json.load(file)
    print(f"✅ Successfully loaded {len(acts_data)} records from case data.")
except FileNotFoundError:
    print(f"❌ Error: The file was not found at {file_path}")
    print("Please ensure the file path is correct and that your Google Drive is mounted if you're using Colab.")
    acts_data = []
# Out:
# ✅ Successfully loaded 32 records from case data.

# %%
try:
  neo4j_conn = Neo4jConnector(uri=NEO4J_URI, user=NEO4J_USER, password=NEO4J_PASSWORD)
  neo4j_conn.verify_connection()

  for act in acts_data:
    act_title = act['title']
    filename = act["filename"]
    doc_id = act["id"]

    standardizer = ActStandardizer()
    structured_act = standardizer.standardize(act_title)

    # Format the final string as "Name_X_YYYY"
    formatted_string = f"{structured_act['act_number']}_{structured_act['year']}_{structured_act['ammend_suffix']}"


    metadata = {
        "title": act_title,
        "filename": filename,
        "doc_id": doc_id,
        "act_name": structured_act["act_name"],
        "act_number": structured_act["act_number"],
        "act_year": structured_act["year"],
        "doc_year": DOC_YEAR
    }
    neo4j_conn.set_act_metadata(formatted_string, metadata, True)
    print(f"==> Pushed to '{formatted_string}' with metadata.")

except Exception as e:
  print(f"❌ An error occurred during the Neo4j push operation: {e}")

finally:
  if neo4j_conn:
      neo4j_conn.close()
      print("Neo4j push connection closed.")
# Out:
# ✅ Connection to Neo4j AuraDB verified successfully.
# ==> Pushed to '26_2024_amendment' with metadata.
# ==> Pushed to '28_2024_amendment' with metadata.
# ==> Pushed to '21_2024_amendment' with metadata.
# ==> Pushed to '19_2024_amendment' with metadata.
# ==> Pushed to '22_2024_amendment' with metadata.
# ==> Pushed to '25_2024_amendment' with metadata.
# ==> Pushed to '16_2024_amendment' with metadata.
# ==> Pushed to '18_2024_amendment' with metadata.
# ==> Pushed to '15_2024_amendment' with metadata.
# ==> Pushed to '11_2024_amendment' with metadata.
# ==> Pushed to '23_2024_amendment' with metadata.
# ==> Pushed to '27_2024_amendment' with metadata.
# ==> Pushed to '3_2024_original' with metadata.
# ==> Pushed to '29_2024_original' with metadata.
# ==> Pushed to '30_2024_original' with metadata.
# ==> Pushed to '20_2024_amendment' with metadata.
# ==> Pushed to '32_2024_original' with metadata.
# ==> Pushed to '4_2024_amendment' with metadata.
# ...

# %%
# ❓ Query a Specific Case and Display Results

def parse_standardized_act_name(act_name_str):
    """Parses a standardized act name back into its components for display."""
    parsing_pattern = re.compile(r'^(.*)\s+No\.\s+(\d+)\s+of\s+(\d{4})$')
    match = parsing_pattern.match(act_name_str)
    if match:
        return {"act_name": match.group(1).strip(), "act_number": match.group(2), "year": match.group(3)}
    return {"act_name": act_name_str, "act_number": "N/A", "year": "N/A"}

# --- CONFIGURATION ---
# <<-- CHANGE THIS ID to the case you want to query from your data
target_case_id = "4c4ebba0-1876-43ba-adf6-79afca98fceb" # Example case ID

print(f"\n--- Phase 2: Querying Data ---")
print(f"\nQuerying for acts referred by Case ID: '{target_case_id}'")

neo4j_conn = None
try:
    neo4j_conn = Neo4jConnector(uri=NEO4J_URI, user=NEO4J_USER, password=NEO4J_PASSWORD)
    neo4j_conn.verify_connection()

    referred_acts = neo4j_conn.get_acts_for_case(target_case_id)

    if referred_acts:
        print(f"Found {len(referred_acts)} referred act(s). Formatting output...")
        formatted_acts = [parse_standardized_act_name(act) for act in referred_acts]

        # Display the results in a clean pandas DataFrame
        acts_df = pd.DataFrame(formatted_acts)
        acts_df = acts_df[["act_name", "act_number", "year"]] # Ensure column order
        display(acts_df)
    else:
        print(f"No referred acts found in the database for Case ID: '{target_case_id}'")

except Exception as e:
    print(f"❌ An error occurred during the Neo4j query operation: {e}")

finally:
    if neo4j_conn:
        neo4j_conn.close()
        print("Neo4j query connection closed.")
# Out:
# --- Phase 2: Querying Data ---
#
# Querying for acts referred by Case ID: '4c4ebba0-1876-43ba-adf6-79afca98fceb'
# ✅ Connection to Neo4j AuraDB verified successfully.
# /tmp/ipython-input-41-3892089394.py:94: DeprecationWarning: read_transaction has been renamed to execute_read
#   return session.read_transaction(self._get_acts_tx, case_id)
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: id)} {position: line: 1, column: 16, offset: 15} for query: 'MATCH (c:Case {id: $case_id})-[:REFERS_TO]->(a:Act) RETURN a.name AS act_name'
# ...
