# %% [markdown]
# <a href="https://colab.research.google.com/github/HackElite-FYP/Legal-Research-Platform-Core/blob/feature%2Fentity-mapping/entity-mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 96.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# %pip install pandas

# %%
# %pip install py2neo neo4j
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.3/312.3 kB 12.5 MB/s eta 0:00:00
# ...

# %%
import json
import pandas as pd
import re
import spacy
from collections import defaultdict
from spacy.pipeline import EntityRuler

# Load spaCy's small English model
nlp = spacy.load("en_core_web_sm")

# Define robust custom patterns for legal roles and entities
patterns = [
    {
        "label": "JUDGE",
        "pattern": [
            {"IS_TITLE": True, "OP": "+"},
            {"TEXT": ",", "OP": "?"},
            {"LOWER": "j"},
            {"TEXT": ".", "OP": "?"}
        ]
    },
    {
        "label": "LEGAL_ROLE",
        "pattern": [{"IS_TITLE": True, "OP": "+"}, {"LOWER": {"IN": ["asg", "counsel", "judge"]}}]
    },
    {
        "label": "ORG",
        "pattern": [{"LOWER": {"IN": ["court", "department", "ministry", "magistrate", "analyst"]}}]
    }
]

# Set up EntityRuler before the NER
if "entity_ruler" not in nlp.pipe_names:
    ruler = nlp.add_pipe("entity_ruler", before="ner")
else:
    ruler = nlp.get_pipe("entity_ruler")
ruler.add_patterns(patterns)

# Function to extract entities from text
def extract_entities(text):
    doc = nlp(text)
    entities = defaultdict(set)

    for ent in doc.ents:
        if ent.label_ in ["PERSON", "JUDGE", "LEGAL_ROLE"]:
            clean_name = re.sub(r',\s*J\.?$', '', ent.text).strip()
            entities["People"].add(clean_name)
        elif ent.label_ == "ORG":
            entities["Organizations"].add(ent.text.strip())
        elif ent.label_ in ["GPE", "LOC"]:
            entities["Locations"].add(ent.text.strip())
        elif ent.label_ == "DATE":
            entities["Dates"].add(ent.text.strip())
    return entities

# Fix misclassified people/locations
def post_process_and_clean_entities(entities):
    location_keywords = ['Court', 'Gampaha', 'Colombo', 'Weliweriya']
    final = {k: set() for k in ["People", "Organizations", "Locations", "Dates"]}

    for k, values in entities.items():
        for v in values:
            if k == "People" and any(loc in v for loc in location_keywords):
                final["Locations"].add(v)
            elif k == "Locations" and re.match(r'^([A-Z]\.\s*)*[A-Z][a-z]+$', v):
                final["People"].add(v)
            else:
                final[k].add(v)
    return {k: list(sorted(v)) for k, v in final.items()}

# %%
filename = "cases_2024_v2.json"
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1meeq_pyxndS9W7mmavcX_srExlpYi5Hw' -O {filename}
# Out:
# --2025-07-21 14:42:05--  https://docs.google.com/uc?export=download&id=1meeq_pyxndS9W7mmavcX_srExlpYi5Hw
# Resolving docs.google.com (docs.google.com)... 173.194.193.102, 173.194.193.113, 173.194.193.138, ...
# Connecting to docs.google.com (docs.google.com)|173.194.193.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1meeq_pyxndS9W7mmavcX_srExlpYi5Hw&export=download [following]
# --2025-07-21 14:42:06--  https://drive.usercontent.google.com/download?id=1meeq_pyxndS9W7mmavcX_srExlpYi5Hw&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.126.132, 2607:f8b0:4001:c1d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.126.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30688975 (29M) [application/octet-stream]
# Saving to: ‘cases_2024_v2.json’
#
# ...

# %%
import json

# Load data
file_path = f"/content/{filename}"
with open(file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
import concurrent.futures
import pandas as pd
import re

def process_case(case):
    case_id = case.get("id", "Unknown")
    primary_lang = case.get("primaryLang", "Unknown")
    text = case.get("translated", "")
    sections = [s['section'] for s in case.get("structuredSections", [])]
    cleaned_text = re.sub(r'\s+', ' ', text).strip()

    # These must be globally available functions or imported
    raw_entities = extract_entities(cleaned_text)
    clean_entities = post_process_and_clean_entities(raw_entities)

    return {
        "ID": case_id,
        "Judge": sections[0] if len(sections) > 0 else None,
        "Seconded": sections[1] if len(sections) > 1 else None,
        "Language": primary_lang,
        "People": ", ".join(clean_entities.get("People", [])),
        "Organizations": ", ".join(clean_entities.get("Organizations", [])),
        "Locations": ", ".join(clean_entities.get("Locations", [])),
        "Dates": ", ".join(clean_entities.get("Dates", [])),
        "Text": cleaned_text[:500]
    }


with concurrent.futures.ProcessPoolExecutor() as executor:
    cases = list(executor.map(process_case, data))

# Convert to DataFrame
entity_df = pd.DataFrame(cases)

# %%
display(entity_df)
# Out:
#                                        ID                      Judge  \
# 0    8fb1373c-2b19-4df4-bbcc-40b0720dc9b3           B. Abayakoon, J.
# 1    f377d509-ea0d-4a2f-9e7a-4d2a14515d19  M. T. MOHAMMED LAFFAR, J.
# 2    3f222e28-d9a0-452e-aa98-498d5656613e           B. Abayakoon, J.
# 3    9eaa002e-2133-40a3-97ec-3bf16d5829f8           B. Abayakoon, J.
# 4    2d8f6172-6e23-4841-8b6e-70952dfc1cdc           B. Abayakoon, J.
# ..                                    ...                        ...
# 525  8aae1282-9448-4ade-9b70-8b0eb59eb80a     Sobhitha Rajakaruna J.
# 526  2cf9f0ee-1df2-44b2-a891-4415f9174e89        P. Kumararatnam, J.
# 527  46985ee6-bf08-4b7d-a92c-bb83bbf5266e           B. Abayakoon, J.
# 528  95885351-817c-4d60-97aa-206204a40420             Gunawardena J.
# 529  6430a362-68aa-4217-9797-2645d1e3baab  M. T. Mohammed Laffar, J.
#
#                                               Seconded   Language  \
# 0                                  P. Kumararatnam, J.  en (0.75)
# ...

# %%
NEO4J_URI = "neo4j+s://66d16355.databases.neo4j.io"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "G4UXZ6KLGd1dzo57rp6ITypJHZ37aM1fn-exAWdw3p8"

# 🧠 Neo4j Connector Class

from neo4j import GraphDatabase

class Neo4jConnector:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        """Closes the database connection."""
        if self.driver:
            self.driver.close()

    def verify_connection(self):
        """Verifies and prints the connection status."""
        self.driver.verify_connectivity()
        print("✅ Connection to Neo4j AuraDB verified successfully.")

    def create_person_node(self, case_id, person, relationship, meta):
        """Create person node"""
        with self.driver.session(database="neo4j") as session:
            session.execute_write(self.create_person_node_tx, case_id, person, relationship, meta)

    @staticmethod
    def create_person_node_tx(tx, case_id, person, relationship, meta):
        """Create person node"""
        # MERGE node and relationship (relationship needs string interpolation)
        query = f"""
            MERGE (c:Case {{doc_id: $case_id}})
            MERGE (p:Person {{p_id: $person}})
            MERGE (p)-[:{relationship}]->(c)
        """
        tx.run(query, case_id=case_id, person=person)

        # Add meta properties
        if meta:
            set_clauses = ", ".join([f"p.{key} = ${key}" for key in meta])
            meta_query = f"""
                MATCH (p:Person {{p_id: $person}})
                SET {set_clauses}
            """
            tx.run(meta_query, person=person, **meta)

    def set_case_metadata(self, case_id, metadata: dict):
        """Sets or updates metadata for a given Case node."""
        with self.driver.session(database="neo4j") as session:
            session.execute_write(self._update_metadata_tx, case_id, metadata)

    @staticmethod
    def _update_metadata_tx(tx, case_id, metadata: dict):
        # Build a dynamic Cypher SET clause for all metadata keys
        print(metadata)
        set_clause = ', '.join([f"c.{key} = ${key}" for key in metadata])
        parameters = {"case_id": case_id, **metadata}

        query = f"""
        MATCH (c:Case {{doc_id: $case_id}})
        SET {set_clause}
        """

        tx.run(query, parameters)

# %%
import re

def standardize_person_name(raw_name: str) -> str:
    # Remove trailing ", J." or "J." (case-insensitive)
    name = re.sub(r",?\s*J\.\s*$", "", raw_name.strip(), flags=re.IGNORECASE)

    # Split into tokens
    tokens = name.split()

    # Extract initials (e.g., 'M.', 'T.', 'S.')
    initials = [t[0].upper() for t in tokens if re.match(r"^[A-Z]\.$", t, re.IGNORECASE)]

    # Extract non-initial name parts (e.g., 'Mohammed', 'Karalliyadde')
    full_tokens = [t.upper() for t in tokens if not re.match(r"^[A-Z]\.$", t, re.IGNORECASE)]

    # Join initials and name parts
    return "_".join(initials + full_tokens)

# %%
# create judge and seconded person nodes
neo4j_conn = None
try:
    neo4j_conn = Neo4jConnector(uri=NEO4J_URI, user=NEO4J_USER, password=NEO4J_PASSWORD)
    neo4j_conn.verify_connection()

    print("Pushing person nodes...\n")

    df_to_process = entity_df
    # display(df_to_process)
    for _, row in df_to_process.iterrows():
        case_id = row["ID"]
        judge = row["Judge"]
        seconded = row["Seconded"]

        if judge:
            std_judge = standardize_person_name(judge)

            neo4j_conn.create_person_node(case_id, standardize_person_name(judge), "JUDGED", {'name':judge})
            if seconded:
              std_seconded = standardize_person_name(seconded)
              if not std_judge == std_seconded:
                neo4j_conn.create_person_node(case_id, standardize_person_name(seconded), "SECONDED", {'name':seconded})

        print(f"==> Pushed person nodes for case {case_id}. --judge:{judge}, --seconded:{seconded}")

    print(f"\n✅ Successfully processed {len(df_to_process)} cases with person nodes and relationships.")


except Exception as e:
    print(f"❌ An error occurred during the Neo4j push operation: {e}")
# Out:
# ✅ Connection to Neo4j AuraDB verified successfully.
# Pushing person nodes...
#
# ==> Pushed person nodes for case 8fb1373c-2b19-4df4-bbcc-40b0720dc9b3. --judge:B. Abayakoon, J., --seconded:P. Kumararatnam, J.
# ==> Pushed person nodes for case f377d509-ea0d-4a2f-9e7a-4d2a14515d19. --judge:M. T. MOHAMMED LAFFAR, J., --seconded:S. U. B. KARALLIYADDE, J.
# ==> Pushed person nodes for case 3f222e28-d9a0-452e-aa98-498d5656613e. --judge:B. Abayakoon, J., --seconded:P. Kumararatnam, J.
# ==> Pushed person nodes for case 9eaa002e-2133-40a3-97ec-3bf16d5829f8. --judge:B. Abayakoon, J., --seconded:P. Kumararatnam, J.
# ==> Pushed person nodes for case 2d8f6172-6e23-4841-8b6e-70952dfc1cdc. --judge:B. Abayakoon, J., --seconded:B. ABAYAKOON, J.
# ==> Pushed person nodes for case eaaf5922-459d-46c6-8a6d-7d943cf59802. --judge:M. T. MOHAMMED LAFFAR, J., --seconded:None
# ...
